# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvi181998/Covid-19-Analysis/blob/main/Covid_19_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset Link:-"https://docs.google.com/spreadsheets/d/1ssHZ6mEqxUBd3NhGCjvUzL4v-yBv3Qal/edit?usp=sharing&ouid=108640748578588520379&rtpof=true&sd=true"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
path = '/content/drive/MyDrive/Python-April/Data Science/Major Project/owid-covid-data.xlsx'
df = pd.read_excel(path)
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
print('Shape of the dataframe: ',df.shape)
print('')
print('Null Values Statistics: ')
print('')
print(df.isnull().sum())
# Out:
# Shape of the dataframe:  (93737, 59)
#
# Null Values Statistics:
#
# iso_code                                     0
# continent                                 4435
# location                                     0
# date                                         0
# total_cases                               2982
# new_cases                                 2983
# new_cases_smoothed                        3995
# total_deaths                             12937
# new_deaths                               12779
# new_deaths_smoothed                       3995
# total_cases_per_million                   3467
# new_cases_per_million                     3468
# new_cases_smoothed_per_million            4475
# total_deaths_per_million                 13409
# new_deaths_per_million                   13251
# new_deaths_smoothed_per_million           4475
# reproduction_rate                        18346
# icu_patients                             84241
# icu_patients_per_million                 84241
# hosp_patients                            81945
# hosp_patients_per_million                81945
# weekly_icu_admissions                    92877
# weekly_icu_admissions_per_million        92877
# weekly_hosp_admissions                   92241
# weekly_hosp_admissions_per_million       92241
# new_tests                                51493
# total_tests                              51803
# total_tests_per_thousand                 51803
# new_tests_per_thousand                   51493
# new_tests_smoothed                       44784
# new_tests_smoothed_per_thousand          44784
# positive_rate                            47605
# tests_per_case                           48204
# tests_units                              43197
# total_vaccinations                       80231
# people_vaccinated                        81010
# people_fully_vaccinated                  83739
# new_vaccinations                         82409
# new_vaccinations_smoothed                70786
# total_vaccinations_per_hundred           80231
# people_vaccinated_per_hundred            81010
# people_fully_vaccinated_per_hundred      83739
# new_vaccinations_smoothed_per_million    70786
# stringency_index                         14759
# population                                 619
# population_density                        6573
# median_age                                9679
# aged_65_older                            10627
# aged_70_older                            10145
# gdp_per_capita                            9417
# extreme_poverty                          36713
# cardiovasc_death_rate                     9280
# diabetes_prevalence                       7279
# female_smokers                           27637
# male_smokers                             28606
# handwashing_facilities                   51309
# hospital_beds_per_thousand               16753
# life_expectancy                           4727
# human_development_index                   9108
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93737 entries, 0 to 93736
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93737 non-null  object
#  1   continent                              89302 non-null  object
#  2   location                               93737 non-null  object
#  3   date                                   93737 non-null  object
#  4   total_cases                            90755 non-null  float64
#  5   new_cases                              90754 non-null  float64
#  6   new_cases_smoothed                     89742 non-null  float64
#  7   total_deaths                           80800 non-null  float64
#  8   new_deaths                             80958 non-null  float64
#  9   new_deaths_smoothed                    89742 non-null  float64
#  10  total_cases_per_million                90270 non-null  float64
#  11  new_cases_per_million                  90269 non-null  float64
#  12  new_cases_smoothed_per_million         89262 non-null  float64
#  13  total_deaths_per_million               80328 non-null  float64
#  14  new_deaths_per_million                 80486 non-null  float64
#  15  new_deaths_smoothed_per_million        89262 non-null  float64
#  16  reproduction_rate                      75391 non-null  float64
#  17  icu_patients                           9496 non-null   float64
#  18  icu_patients_per_million               9496 non-null   float64
#  19  hosp_patients                          11792 non-null  float64
#  20  hosp_patients_per_million              11792 non-null  float64
#  21  weekly_icu_admissions                  860 non-null    float64
#  22  weekly_icu_admissions_per_million      860 non-null    float64
#  23  weekly_hosp_admissions                 1496 non-null   float64
#  24  weekly_hosp_admissions_per_million     1496 non-null   float64
#  25  new_tests                              42244 non-null  float64
#  26  total_tests                            41934 non-null  float64
#  27  total_tests_per_thousand               41934 non-null  float64
#  28  new_tests_per_thousand                 42244 non-null  float64
#  29  new_tests_smoothed                     48953 non-null  float64
#  30  new_tests_smoothed_per_thousand        48953 non-null  float64
#  31  positive_rate                          46132 non-null  float64
#  32  tests_per_case                         45533 non-null  float64
#  33  tests_units                            50540 non-null  object
#  34  total_vaccinations                     13506 non-null  float64
#  35  people_vaccinated                      12727 non-null  float64
#  36  people_fully_vaccinated                9998 non-null   float64
#  37  new_vaccinations                       11328 non-null  float64
#  38  new_vaccinations_smoothed              22951 non-null  float64
#  39  total_vaccinations_per_hundred         13506 non-null  float64
#  40  people_vaccinated_per_hundred          12727 non-null  float64
#  41  people_fully_vaccinated_per_hundred    9998 non-null   float64
#  42  new_vaccinations_smoothed_per_million  22951 non-null  float64
#  43  stringency_index                       78978 non-null  float64
#  44  population                             93118 non-null  float64
#  45  population_density                     87164 non-null  float64
#  46  median_age                             84058 non-null  float64
#  47  aged_65_older                          83110 non-null  float64
#  48  aged_70_older                          83592 non-null  float64
#  49  gdp_per_capita                         84320 non-null  float64
#  50  extreme_poverty                        57024 non-null  float64
#  51  cardiovasc_death_rate                  84457 non-null  float64
#  52  diabetes_prevalence                    86458 non-null  float64
#  53  female_smokers                         66100 non-null  float64
#  54  male_smokers                           65131 non-null  float64
#  55  handwashing_facilities                 42428 non-null  float64
#  56  hospital_beds_per_thousand             76984 non-null  float64
#  57  life_expectancy                        89010 non-null  float64
#  58  human_development_index                84629 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 42.2+ MB

# %%
df_asia = df[df['continent'] == 'Asia']
df_asia.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
df_asia.reset_index(drop=True, inplace=True)

# %%
df_asia.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 22317      YEM      Asia    Yemen  2021-06-01       6751.0        9.0
# 22318      YEM      Asia    Yemen  2021-06-02       6759.0        8.0
# 22319      YEM      Asia    Yemen  2021-06-03       6767.0        8.0
# 22320      YEM      Asia    Yemen  2021-06-04       6773.0        6.0
# 22321      YEM      Asia    Yemen  2021-06-05       6780.0        7.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 22317              11.571        1322.0         1.0                1.571  ...
# 22318              10.143        1323.0         1.0                1.429  ...
# 22319              10.143        1325.0         2.0                1.429  ...
# 22320               7.143        1325.0         0.0                1.286  ...
# 22321               7.000        1325.0         0.0                0.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 22317        1479.147             18.8                495.003
# 22318        1479.147             18.8                495.003
# 22319        1479.147             18.8                495.003
# 22320        1479.147             18.8                495.003
# 22321        1479.147             18.8                495.003
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 22317                 5.35             7.6          29.2
# 22318                 5.35             7.6          29.2
# 22319                 5.35             7.6          29.2
# 22320                 5.35             7.6          29.2
# 22321                 5.35             7.6          29.2
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 22317                  49.542                         0.7            66.12
# 22318                  49.542                         0.7            66.12
# 22319                  49.542                         0.7            66.12
# 22320                  49.542                         0.7            66.12
# 22321                  49.542                         0.7            66.12
#
#        human_development_index
# 22317                     0.47
# 22318                     0.47
# 22319                     0.47
# 22320                     0.47
# 22321                     0.47
#
# [5 rows x 59 columns]

# %%
df_asia.shape
# Out:
# (22322, 59)

# %%
df_asia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22322 entries, 0 to 22321
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               22322 non-null  object
#  1   continent                              22322 non-null  object
#  2   location                               22322 non-null  object
#  3   date                                   22322 non-null  object
#  4   total_cases                            22038 non-null  float64
#  5   new_cases                              22033 non-null  float64
#  6   new_cases_smoothed                     21798 non-null  float64
#  7   total_deaths                           19000 non-null  float64
#  8   new_deaths                             18999 non-null  float64
#  9   new_deaths_smoothed                    21798 non-null  float64
#  10  total_cases_per_million                22038 non-null  float64
#  11  new_cases_per_million                  22033 non-null  float64
#  12  new_cases_smoothed_per_million         21798 non-null  float64
#  13  total_deaths_per_million               19000 non-null  float64
#  14  new_deaths_per_million                 18999 non-null  float64
#  15  new_deaths_smoothed_per_million        21798 non-null  float64
#  16  reproduction_rate                      19196 non-null  float64
#  17  icu_patients                           292 non-null    float64
#  18  icu_patients_per_million               292 non-null    float64
#  19  hosp_patients                          460 non-null    float64
#  20  hosp_patients_per_million              460 non-null    float64
#  21  weekly_icu_admissions                  65 non-null     float64
#  22  weekly_icu_admissions_per_million      65 non-null     float64
#  23  weekly_hosp_admissions                 65 non-null     float64
#  24  weekly_hosp_admissions_per_million     65 non-null     float64
#  25  new_tests                              11451 non-null  float64
#  26  total_tests                            11673 non-null  float64
#  27  total_tests_per_thousand               11673 non-null  float64
#  28  new_tests_per_thousand                 11451 non-null  float64
#  29  new_tests_smoothed                     13444 non-null  float64
#  30  new_tests_smoothed_per_thousand        13444 non-null  float64
#  31  positive_rate                          12963 non-null  float64
#  32  tests_per_case                         12814 non-null  float64
#  33  tests_units                            13775 non-null  object
#  34  total_vaccinations                     2982 non-null   float64
#  35  people_vaccinated                      2542 non-null   float64
#  36  people_fully_vaccinated                1776 non-null   float64
#  37  new_vaccinations                       2465 non-null   float64
#  38  new_vaccinations_smoothed              5282 non-null   float64
#  39  total_vaccinations_per_hundred         2982 non-null   float64
#  40  people_vaccinated_per_hundred          2542 non-null   float64
#  41  people_fully_vaccinated_per_hundred    1776 non-null   float64
#  42  new_vaccinations_smoothed_per_million  5282 non-null   float64
#  43  stringency_index                       20965 non-null  float64
#  44  population                             22188 non-null  float64
#  45  population_density                     21240 non-null  float64
#  46  median_age                             22188 non-null  float64
#  47  aged_65_older                          21240 non-null  float64
#  48  aged_70_older                          22188 non-null  float64
#  49  gdp_per_capita                         21240 non-null  float64
#  50  extreme_poverty                        13051 non-null  float64
#  51  cardiovasc_death_rate                  21570 non-null  float64
#  52  diabetes_prevalence                    21122 non-null  float64
#  53  female_smokers                         17908 non-null  float64
#  54  male_smokers                           17908 non-null  float64
#  55  handwashing_facilities                 11557 non-null  float64
#  56  hospital_beds_per_thousand             20150 non-null  float64
#  57  life_expectancy                        22188 non-null  float64
#  58  human_development_index                21563 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 10.0+ MB

# %%
df_asia.isnull().sum()
# Out:
# iso_code                                     0
# continent                                    0
# location                                     0
# date                                         0
# total_cases                                284
# new_cases                                  289
# new_cases_smoothed                         524
# total_deaths                              3322
# new_deaths                                3323
# new_deaths_smoothed                        524
# total_cases_per_million                    284
# new_cases_per_million                      289
# new_cases_smoothed_per_million             524
# total_deaths_per_million                  3322
# new_deaths_per_million                    3323
# new_deaths_smoothed_per_million            524
# reproduction_rate                         3126
# icu_patients                             22030
# icu_patients_per_million                 22030
# hosp_patients                            21862
# hosp_patients_per_million                21862
# weekly_icu_admissions                    22257
# weekly_icu_admissions_per_million        22257
# weekly_hosp_admissions                   22257
# weekly_hosp_admissions_per_million       22257
# new_tests                                10871
# total_tests                              10649
# total_tests_per_thousand                 10649
# new_tests_per_thousand                   10871
# new_tests_smoothed                        8878
# new_tests_smoothed_per_thousand           8878
# positive_rate                             9359
# tests_per_case                            9508
# tests_units                               8547
# total_vaccinations                       19340
# people_vaccinated                        19780
# people_fully_vaccinated                  20546
# new_vaccinations                         19857
# new_vaccinations_smoothed                17040
# total_vaccinations_per_hundred           19340
# people_vaccinated_per_hundred            19780
# people_fully_vaccinated_per_hundred      20546
# new_vaccinations_smoothed_per_million    17040
# stringency_index                          1357
# population                                 134
# population_density                        1082
# median_age                                 134
# aged_65_older                             1082
# aged_70_older                              134
# gdp_per_capita                            1082
# extreme_poverty                           9271
# cardiovasc_death_rate                      752
# diabetes_prevalence                       1200
# female_smokers                            4414
# male_smokers                              4414
# handwashing_facilities                   10765
# hospital_beds_per_thousand                2172
# life_expectancy                            134
# human_development_index                    759
# dtype: int64

# %%
df_asia['location'].unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei', 'Cambodia', 'China', 'Georgia', 'Hong Kong',
#        'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Macao',
#        'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal',
#        'Northern Cyprus', 'Oman', 'Pakistan', 'Palestine', 'Philippines',
#        'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka',
#        'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Timor', 'Turkey',
#        'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam',
#        'Yemen'], dtype=object)

# %%
df_asia['date'] = pd.to_datetime(df_asia['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_asia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22322 entries, 0 to 22321
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               22322 non-null  object
#  1   continent                              22322 non-null  object
#  2   location                               22322 non-null  object
#  3   date                                   22322 non-null  datetime64[ns]
#  4   total_cases                            22038 non-null  float64
#  5   new_cases                              22033 non-null  float64
#  6   new_cases_smoothed                     21798 non-null  float64
#  7   total_deaths                           19000 non-null  float64
#  8   new_deaths                             18999 non-null  float64
#  9   new_deaths_smoothed                    21798 non-null  float64
#  10  total_cases_per_million                22038 non-null  float64
#  11  new_cases_per_million                  22033 non-null  float64
#  12  new_cases_smoothed_per_million         21798 non-null  float64
#  13  total_deaths_per_million               19000 non-null  float64
#  14  new_deaths_per_million                 18999 non-null  float64
#  15  new_deaths_smoothed_per_million        21798 non-null  float64
#  16  reproduction_rate                      19196 non-null  float64
#  17  icu_patients                           292 non-null    float64
#  18  icu_patients_per_million               292 non-null    float64
#  19  hosp_patients                          460 non-null    float64
#  20  hosp_patients_per_million              460 non-null    float64
#  21  weekly_icu_admissions                  65 non-null     float64
#  22  weekly_icu_admissions_per_million      65 non-null     float64
#  23  weekly_hosp_admissions                 65 non-null     float64
#  24  weekly_hosp_admissions_per_million     65 non-null     float64
#  25  new_tests                              11451 non-null  float64
#  26  total_tests                            11673 non-null  float64
#  27  total_tests_per_thousand               11673 non-null  float64
#  28  new_tests_per_thousand                 11451 non-null  float64
#  29  new_tests_smoothed                     13444 non-null  float64
#  30  new_tests_smoothed_per_thousand        13444 non-null  float64
#  31  positive_rate                          12963 non-null  float64
#  32  tests_per_case                         12814 non-null  float64
#  33  tests_units                            13775 non-null  object
#  34  total_vaccinations                     2982 non-null   float64
#  35  people_vaccinated                      2542 non-null   float64
#  36  people_fully_vaccinated                1776 non-null   float64
#  37  new_vaccinations                       2465 non-null   float64
#  38  new_vaccinations_smoothed              5282 non-null   float64
#  39  total_vaccinations_per_hundred         2982 non-null   float64
#  40  people_vaccinated_per_hundred          2542 non-null   float64
#  41  people_fully_vaccinated_per_hundred    1776 non-null   float64
#  42  new_vaccinations_smoothed_per_million  5282 non-null   float64
#  43  stringency_index                       20965 non-null  float64
#  44  population                             22188 non-null  float64
#  45  population_density                     21240 non-null  float64
#  46  median_age                             22188 non-null  float64
#  47  aged_65_older                          21240 non-null  float64
#  48  aged_70_older                          22188 non-null  float64
#  49  gdp_per_capita                         21240 non-null  float64
#  50  extreme_poverty                        13051 non-null  float64
#  51  cardiovasc_death_rate                  21570 non-null  float64
#  52  diabetes_prevalence                    21122 non-null  float64
#  53  female_smokers                         17908 non-null  float64
#  54  male_smokers                           17908 non-null  float64
#  55  handwashing_facilities                 11557 non-null  float64
#  56  hospital_beds_per_thousand             20150 non-null  float64
#  57  life_expectancy                        22188 non-null  float64
#  58  human_development_index                21563 non-null  float64
# dtypes: datetime64[ns](1), float64(54), object(4)
# memory usage: 10.0+ MB

# %%
plt.figure(figsize=(20,5))
plt.plot(df_asia['date'].sort_values(),df_asia['new_cases_smoothed'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_asia['date'].sort_values(),df_asia['new_vaccinations_smoothed_per_million'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_asia['date'].sort_values(),df_asia['total_cases'])

# %% [markdown]
# # Forecasting (Asia)

# %% [markdown]
# Cases

# %% [markdown]
# > 1.New Cases

# %%
df_asia = df_asia.drop(columns=['icu_patients','icu_patients_per_million','hosp_patients','hosp_patients_per_million','total_vaccinations','people_vaccinated','people_fully_vaccinated','new_vaccinations','new_vaccinations_smoothed','total_vaccinations_per_hundred','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','new_vaccinations_smoothed_per_million'])
df_asia = df_asia.drop(columns=['weekly_icu_admissions','weekly_icu_admissions_per_million','weekly_hosp_admissions','weekly_hosp_admissions_per_million'])

# %%
df_asia_newcases = df_asia.copy()

# %%
df_asia_newcases = df_asia_newcases.rename(columns={'date':'ds','new_cases_smoothed':'y'})

# %%
df_asia_newcases.head()
# Out:
#   iso_code continent     location         ds  total_cases  new_cases   y  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0 NaN
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0 NaN
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0 NaN
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0 NaN
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0 NaN
#
#    total_deaths  new_deaths  new_deaths_smoothed  ...  gdp_per_capita  \
# 0           NaN         NaN                  NaN  ...        1803.987
# 1           NaN         NaN                  NaN  ...        1803.987
# 2           NaN         NaN                  NaN  ...        1803.987
# 3           NaN         NaN                  NaN  ...        1803.987
# 4           NaN         NaN                  NaN  ...        1803.987
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 42 columns]

# %%
df_asia_newcases.shape
# Out:
# (22322, 42)

# %%
df_asia_newcases.sort_values('ds',inplace=True)

# %%
df_asia_newcases.head()
# Out:
#       iso_code continent  location         ds  total_cases  new_cases   y  \
# 19045      THA      Asia  Thailand 2020-01-04          NaN        NaN NaN
# 19046      THA      Asia  Thailand 2020-01-05          NaN        NaN NaN
# 19047      THA      Asia  Thailand 2020-01-06          NaN        NaN NaN
# 19048      THA      Asia  Thailand 2020-01-07          NaN        NaN NaN
# 19049      THA      Asia  Thailand 2020-01-08          NaN        NaN NaN
#
#        total_deaths  new_deaths  new_deaths_smoothed  ...  gdp_per_capita  \
# 19045           NaN         NaN                  NaN  ...       16277.671
# 19046           NaN         NaN                  NaN  ...       16277.671
# 19047           NaN         NaN                  NaN  ...       16277.671
# 19048           NaN         NaN                  NaN  ...       16277.671
# 19049           NaN         NaN                  NaN  ...       16277.671
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 19045              0.1                109.861                 7.04
# 19046              0.1                109.861                 7.04
# 19047              0.1                109.861                 7.04
# 19048              0.1                109.861                 7.04
# 19049              0.1                109.861                 7.04
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 19045             1.9          38.8                   90.67
# 19046             1.9          38.8                   90.67
# 19047             1.9          38.8                   90.67
# 19048             1.9          38.8                   90.67
# 19049             1.9          38.8                   90.67
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index
# 19045                         2.1            77.15                    0.777
# 19046                         2.1            77.15                    0.777
# 19047                         2.1            77.15                    0.777
# 19048                         2.1            77.15                    0.777
# 19049                         2.1            77.15                    0.777
#
# [5 rows x 42 columns]

# %%
from fbprophet import Prophet

# %%
model = Prophet()
model.fit(df_asia_newcases)
x = model.make_future_dataframe(periods= 30, freq='D')
forecast = model.predict(x)
forecast
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-01-04   -207.735859 -20129.598025  19579.371068   -207.735859
# 1   2020-01-05   -203.413620 -20592.545536  20661.047523   -203.413620
# 2   2020-01-06   -199.091382 -20215.669871  20102.839077   -199.091382
# 3   2020-01-07   -194.769143 -19909.055176  20282.870115   -194.769143
# 4   2020-01-08   -190.446904 -20852.330158  21219.971921   -190.446904
# ..         ...           ...           ...           ...           ...
# 544 2021-07-01  11773.049950  -8902.395270  32662.996130  11654.871523
# 545 2021-07-02  11853.045759  -8374.868297  33099.872780  11725.985588
# 546 2021-07-03  11933.041568  -8400.184195  32214.241769  11797.510097
# 547 2021-07-04  12013.037376  -6868.434687  32378.401033  11865.383336
# 548 2021-07-05  12093.033185  -8870.366948  32802.316188  11935.935506
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0     -207.735859      -36.135512            -36.135512            -36.135512
# 1     -203.413620       34.383857             34.383857             34.383857
# 2     -199.091382       22.518760             22.518760             22.518760
# 3     -194.769143       11.701532             11.701532             11.701532
# 4     -190.446904        0.608361              0.608361              0.608361
# ..            ...             ...                   ...                   ...
# 544  11896.756336      -10.386831            -10.386831            -10.386831
# 545  11984.311598      -22.690168            -22.690168            -22.690168
# 546  12071.601348      -36.135512            -36.135512            -36.135512
# 547  12161.612536       34.383857             34.383857             34.383857
# 548  12255.446740       22.518760             22.518760             22.518760
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0   -36.135512    -36.135512    -36.135512                   0.0
# 1    34.383857     34.383857     34.383857                   0.0
# 2    22.518760     22.518760     22.518760                   0.0
# 3    11.701532     11.701532     11.701532                   0.0
# 4     0.608361      0.608361      0.608361                   0.0
# ..         ...           ...           ...                   ...
# 544 -10.386831    -10.386831    -10.386831                   0.0
# 545 -22.690168    -22.690168    -22.690168                   0.0
# 546 -36.135512    -36.135512    -36.135512                   0.0
# 547  34.383857     34.383857     34.383857                   0.0
# 548  22.518760     22.518760     22.518760                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0   -243.871371
# 1                           0.0                         0.0   -169.029764
# 2                           0.0                         0.0   -176.572622
# 3                           0.0                         0.0   -183.067611
# 4                           0.0                         0.0   -189.838542
# ..                          ...                         ...           ...
# 544                         0.0                         0.0  11762.663119
# 545                         0.0                         0.0  11830.355591
# 546                         0.0                         0.0  11896.906056
# 547                         0.0                         0.0  12047.421233
# 548                         0.0                         0.0  12115.551945
#
# [549 rows x 16 columns]

# %%
model.component_modes
# Out:
# {'additive': ['weekly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
df2 = forecast[['ds','trend','yhat_lower','yhat_upper','yhat']]

# %%
df2
# Out:
#             ds         trend    yhat_lower    yhat_upper          yhat
# 0   2020-01-04   -207.735859 -20129.598025  19579.371068   -243.871371
# 1   2020-01-05   -203.413620 -20592.545536  20661.047523   -169.029764
# 2   2020-01-06   -199.091382 -20215.669871  20102.839077   -176.572622
# 3   2020-01-07   -194.769143 -19909.055176  20282.870115   -183.067611
# 4   2020-01-08   -190.446904 -20852.330158  21219.971921   -189.838542
# ..         ...           ...           ...           ...           ...
# 544 2021-07-01  11773.049950  -8902.395270  32662.996130  11762.663119
# 545 2021-07-02  11853.045759  -8374.868297  33099.872780  11830.355591
# 546 2021-07-03  11933.041568  -8400.184195  32214.241769  11896.906056
# 547 2021-07-04  12013.037376  -6868.434687  32378.401033  12047.421233
# 548 2021-07-05  12093.033185  -8870.366948  32802.316188  12115.551945
#
# [549 rows x 5 columns]

# %%
model.plot(df2,figsize=(20,5));

# %%
plt.figure(figsize=(20,5))
plt.plot(df_asia['date'],df_asia['new_cases'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_asia['date'].sort_values(),df_asia['new_cases'])

# %% [markdown]
# > 2.Total Cases

# %%
df_asia.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 42 columns]

# %%
df_asia_totalcases = df_asia.copy()

# %%
df_asia_totalcases = df_asia_totalcases.rename(columns={'date':'ds','total_cases':'y'})
df_asia_totalcases.sort_values('ds',inplace=True)

# %%
model_tc = Prophet()
model_tc.fit(df_asia_totalcases)
x_totalcases = model_tc.make_future_dataframe(periods=30,freq='D')
forecast_tc = model_tc.predict(x)
forecast_tc
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-01-04 -2.039855e+04 -1.967041e+06  1.935828e+06 -2.039855e+04
# 1   2020-01-05 -2.010311e+04 -2.111917e+06  1.789636e+06 -2.010311e+04
# 2   2020-01-06 -1.980767e+04 -1.971424e+06  1.888171e+06 -1.980767e+04
# 3   2020-01-07 -1.951222e+04 -1.958143e+06  1.873016e+06 -1.951222e+04
# 4   2020-01-08 -1.921678e+04 -1.807971e+06  1.888459e+06 -1.921678e+04
# ..         ...           ...           ...           ...           ...
# 544 2021-07-01  1.220094e+06 -6.598100e+05  3.239713e+06  1.212900e+06
# 545 2021-07-02  1.225986e+06 -6.670021e+05  3.163363e+06  1.218340e+06
# 546 2021-07-03  1.231879e+06 -8.226082e+05  3.074073e+06  1.223514e+06
# 547 2021-07-04  1.237771e+06 -6.519386e+05  3.210149e+06  1.228766e+06
# 548 2021-07-05  1.243663e+06 -5.491918e+05  3.131613e+06  1.234367e+06
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0   -2.039855e+04      443.733183            443.733183            443.733183
# 1   -2.010311e+04     -203.488966           -203.488966           -203.488966
# 2   -1.980767e+04     -376.507641           -376.507641           -376.507641
# 3   -1.951222e+04     -356.077359           -356.077359           -356.077359
# 4   -1.921678e+04     -162.164352           -162.164352           -162.164352
# ..            ...             ...                   ...                   ...
# 544  1.225809e+06      278.180368            278.180368            278.180368
# 545  1.232138e+06      376.324767            376.324767            376.324767
# 546  1.238496e+06      443.733183            443.733183            443.733183
# 547  1.245190e+06     -203.488966           -203.488966           -203.488966
# 548  1.251533e+06     -376.507641           -376.507641           -376.507641
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0    443.733183    443.733183    443.733183                   0.0
# 1   -203.488966   -203.488966   -203.488966                   0.0
# 2   -376.507641   -376.507641   -376.507641                   0.0
# 3   -356.077359   -356.077359   -356.077359                   0.0
# 4   -162.164352   -162.164352   -162.164352                   0.0
# ..          ...           ...           ...                   ...
# 544  278.180368    278.180368    278.180368                   0.0
# 545  376.324767    376.324767    376.324767                   0.0
# 546  443.733183    443.733183    443.733183                   0.0
# 547 -203.488966   -203.488966   -203.488966                   0.0
# 548 -376.507641   -376.507641   -376.507641                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0 -1.995482e+04
# 1                           0.0                         0.0 -2.030660e+04
# 2                           0.0                         0.0 -2.018417e+04
# 3                           0.0                         0.0 -1.986830e+04
# 4                           0.0                         0.0 -1.937894e+04
# ..                          ...                         ...           ...
# 544                         0.0                         0.0  1.220372e+06
# 545                         0.0                         0.0  1.226363e+06
# 546                         0.0                         0.0  1.232322e+06
# 547                         0.0                         0.0  1.237568e+06
# 548                         0.0                         0.0  1.243287e+06
#
# [549 rows x 16 columns]

# %%
df_tc = forecast_tc[['ds','yhat_lower','yhat_upper','yhat']]

# %%
model_tc.plot(df_tc,figsize=(20,5));

# %% [markdown]
# Deaths

# %% [markdown]
# > 1.Total Deaths

# %%
df_asia.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 42 columns]

# %%
df_asia_totaldeath = df_asia.copy()

# %%
df_asia_totaldeath = df_asia_totaldeath.rename(columns={'date':'ds','total_deaths':'y'})

# %%
df_asia_totaldeath
# Out:
#       iso_code continent     location         ds  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 22317      YEM      Asia        Yemen 2021-06-01       6751.0        9.0
# 22318      YEM      Asia        Yemen 2021-06-02       6759.0        8.0
# 22319      YEM      Asia        Yemen 2021-06-03       6767.0        8.0
# 22320      YEM      Asia        Yemen 2021-06-04       6773.0        6.0
# 22321      YEM      Asia        Yemen 2021-06-05       6780.0        7.0
#
#        new_cases_smoothed       y  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN     NaN         NaN                  NaN  ...
# 1                     NaN     NaN         NaN                  NaN  ...
# 2                     NaN     NaN         NaN                  NaN  ...
# 3                     NaN     NaN         NaN                  NaN  ...
# 4                     NaN     NaN         NaN                  NaN  ...
# ...                   ...     ...         ...                  ...  ...
# 22317              11.571  1322.0         1.0                1.571  ...
# 22318              10.143  1323.0         1.0                1.429  ...
# 22319              10.143  1325.0         2.0                1.429  ...
# 22320               7.143  1325.0         0.0                1.286  ...
# 22321               7.000  1325.0         0.0                0.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 22317        1479.147             18.8                495.003
# 22318        1479.147             18.8                495.003
# 22319        1479.147             18.8                495.003
# 22320        1479.147             18.8                495.003
# 22321        1479.147             18.8                495.003
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 22317                 5.35             7.6          29.2
# 22318                 5.35             7.6          29.2
# 22319                 5.35             7.6          29.2
# 22320                 5.35             7.6          29.2
# 22321                 5.35             7.6          29.2
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 22317                  49.542                         0.7            66.12
# 22318                  49.542                         0.7            66.12
# 22319                  49.542                         0.7            66.12
# 22320                  49.542                         0.7            66.12
# 22321                  49.542                         0.7            66.12
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 22317                    0.470
# 22318                    0.470
# 22319                    0.470
# 22320                    0.470
# 22321                    0.470
#
# [22322 rows x 42 columns]

# %%
df_asia_totaldeath.sort_values('ds',inplace=True)

# %%
model_td = Prophet()
model_td.fit(df_asia_totaldeath)
x_dc = model_td.make_future_dataframe(periods=30,freq='D')
forecast_td = model_td.predict(x_dc)
forecast_td
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2020-01-04   -752.205059 -27380.080151  26193.667117   -752.205059
# 1   2020-01-05   -741.479928 -26117.858516  25622.171882   -741.479928
# 2   2020-01-06   -730.754796 -28119.568350  28076.993210   -730.754796
# 3   2020-01-07   -720.029665 -25902.647738  25591.030435   -720.029665
# 4   2020-01-08   -709.304533 -27957.398678  25887.578921   -709.304533
# ..         ...           ...           ...           ...           ...
# 544 2021-07-01  15300.606490  -9132.008120  42845.231921  15236.860938
# 545 2021-07-02  15357.482479 -10033.556831  43561.519221  15288.057771
# 546 2021-07-03  15414.358469 -11986.624533  41125.567931  15338.625403
# 547 2021-07-04  15471.234458 -14039.279267  42168.074518  15391.035931
# 548 2021-07-05  15528.110447 -11773.263346  41669.433120  15442.847918
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0     -752.205059       10.361298             10.361298             10.361298
# 1     -741.479928      -10.282844            -10.282844            -10.282844
# 2     -730.754796       -5.939463             -5.939463             -5.939463
# 3     -720.029665       -5.547253             -5.547253             -5.547253
# 4     -709.304533        1.351796              1.351796              1.351796
# ..            ...             ...                   ...                   ...
# 544  15374.698301        4.007886              4.007886              4.007886
# 545  15436.508559        6.048581              6.048581              6.048581
# 546  15498.173461       10.361298             10.361298             10.361298
# 547  15560.238008      -10.282844            -10.282844            -10.282844
# 548  15621.818515       -5.939463             -5.939463             -5.939463
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0    10.361298     10.361298     10.361298                   0.0
# 1   -10.282844    -10.282844    -10.282844                   0.0
# 2    -5.939463     -5.939463     -5.939463                   0.0
# 3    -5.547253     -5.547253     -5.547253                   0.0
# 4     1.351796      1.351796      1.351796                   0.0
# ..         ...           ...           ...                   ...
# 544   4.007886      4.007886      4.007886                   0.0
# 545   6.048581      6.048581      6.048581                   0.0
# 546  10.361298     10.361298     10.361298                   0.0
# 547 -10.282844    -10.282844    -10.282844                   0.0
# 548  -5.939463     -5.939463     -5.939463                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0   -741.843761
# 1                           0.0                         0.0   -751.762772
# 2                           0.0                         0.0   -736.694260
# 3                           0.0                         0.0   -725.576918
# 4                           0.0                         0.0   -707.952737
# ..                          ...                         ...           ...
# 544                         0.0                         0.0  15304.614376
# 545                         0.0                         0.0  15363.531060
# 546                         0.0                         0.0  15424.719767
# 547                         0.0                         0.0  15460.951613
# 548                         0.0                         0.0  15522.170984
#
# [549 rows x 16 columns]

# %%
df_asia_td = forecast_td[['ds','yhat_lower','yhat_upper','yhat']]

# %%
model_td.plot(df_asia_td,figsize=(20,5));

# %% [markdown]
# > 2.New Deaths

# %%
df_asia_newdeath = df_asia.copy()

# %%
df_asia_newdeath = df_asia_newdeath.rename(columns={'date':'ds','new_deaths':'y'})

# %%
df_asia_newdeath.sort_values('ds',inplace=True)
df_asia_newdeath.head()
# Out:
#       iso_code continent  location         ds  total_cases  new_cases  \
# 19045      THA      Asia  Thailand 2020-01-04          NaN        NaN
# 19046      THA      Asia  Thailand 2020-01-05          NaN        NaN
# 19047      THA      Asia  Thailand 2020-01-06          NaN        NaN
# 19048      THA      Asia  Thailand 2020-01-07          NaN        NaN
# 19049      THA      Asia  Thailand 2020-01-08          NaN        NaN
#
#        new_cases_smoothed  total_deaths   y  new_deaths_smoothed  ...  \
# 19045                 NaN           NaN NaN                  NaN  ...
# 19046                 NaN           NaN NaN                  NaN  ...
# 19047                 NaN           NaN NaN                  NaN  ...
# 19048                 NaN           NaN NaN                  NaN  ...
# 19049                 NaN           NaN NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 19045       16277.671              0.1                109.861
# 19046       16277.671              0.1                109.861
# 19047       16277.671              0.1                109.861
# 19048       16277.671              0.1                109.861
# 19049       16277.671              0.1                109.861
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 19045                 7.04             1.9          38.8
# 19046                 7.04             1.9          38.8
# 19047                 7.04             1.9          38.8
# 19048                 7.04             1.9          38.8
# 19049                 7.04             1.9          38.8
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 19045                   90.67                         2.1            77.15
# 19046                   90.67                         2.1            77.15
# 19047                   90.67                         2.1            77.15
# 19048                   90.67                         2.1            77.15
# 19049                   90.67                         2.1            77.15
#
#        human_development_index
# 19045                    0.777
# 19046                    0.777
# 19047                    0.777
# 19048                    0.777
# 19049                    0.777
#
# [5 rows x 42 columns]

# %%
model_nd = Prophet()
model_nd.fit(df_asia_newdeath)
x_nd = model_nd.make_future_dataframe(periods=30,freq='D')
forecast_nd = model_nd.predict(x_nd)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
df_asia_nd = forecast_nd[['ds','yhat_lower','yhat_upper','yhat']]

# %%
model_nd.plot(df_asia_nd,figsize=(20,5));

# %% [markdown]
# # Forecasting(India)

# %%
df_india = df[df['location'] == 'India']
df_india.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 38752      IND      Asia    India  2020-01-30          1.0        1.0
# 38753      IND      Asia    India  2020-01-31          1.0        0.0
# 38754      IND      Asia    India  2020-02-01          1.0        0.0
# 38755      IND      Asia    India  2020-02-02          2.0        1.0
# 38756      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38752                 NaN           NaN         NaN                  NaN  ...
# 38753                 NaN           NaN         NaN                  NaN  ...
# 38754                 NaN           NaN         NaN                  NaN  ...
# 38755                 NaN           NaN         NaN                  NaN  ...
# 38756                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 38752        6426.674             21.2                 282.28
# 38753        6426.674             21.2                 282.28
# 38754        6426.674             21.2                 282.28
# 38755        6426.674             21.2                 282.28
# 38756        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 38752                10.39             1.9          20.6
# 38753                10.39             1.9          20.6
# 38754                10.39             1.9          20.6
# 38755                10.39             1.9          20.6
# 38756                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 38752                   59.55                        0.53            69.66
# 38753                   59.55                        0.53            69.66
# 38754                   59.55                        0.53            69.66
# 38755                   59.55                        0.53            69.66
# 38756                   59.55                        0.53            69.66
#
#        human_development_index
# 38752                    0.645
# 38753                    0.645
# 38754                    0.645
# 38755                    0.645
# 38756                    0.645
#
# [5 rows x 59 columns]

# %%
df_india.fillna(0,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df_india = df_india.rename(columns={'date':'ds','new_cases_smoothed':'y'})

# %%
model1 = Prophet(changepoint_prior_scale=0.2)
model1.fit(df_india)
x1 = model1.make_future_dataframe(periods= 30, freq='D')
forecast1 = model1.predict(x1)
df3 = forecast1[['ds','trend','yhat_lower','yhat_upper','yhat']]
model1.plot(df3,figsize=(20,5));
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Forecasting(Armenia)

# %%
df_Armenia = df[df['location'] == 'Armenia']
df_Armenia.fillna(0,inplace=True)
df_Armenia = df_Armenia.rename(columns={'date':'ds','new_cases_smoothed':'y'})
model2 = Prophet(changepoint_prior_scale=0.2)
model2.fit(df_Armenia)
x2 = model2.make_future_dataframe(periods= 30, freq='D')
forecast2 = model2.predict(x2)
df4 = forecast2[['ds','trend','yhat_lower','yhat_upper','yhat']]
model2.plot(df4,figsize=(20,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# Another copy for calendar graph

# %%
df_copy = df.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93737 entries, 0 to 93736
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93737 non-null  object
#  1   continent                              89302 non-null  object
#  2   location                               93737 non-null  object
#  3   date                                   93737 non-null  object
#  4   total_cases                            90755 non-null  float64
#  5   new_cases                              90754 non-null  float64
#  6   new_cases_smoothed                     89742 non-null  float64
#  7   total_deaths                           80800 non-null  float64
#  8   new_deaths                             80958 non-null  float64
#  9   new_deaths_smoothed                    89742 non-null  float64
#  10  total_cases_per_million                90270 non-null  float64
#  11  new_cases_per_million                  90269 non-null  float64
#  12  new_cases_smoothed_per_million         89262 non-null  float64
#  13  total_deaths_per_million               80328 non-null  float64
#  14  new_deaths_per_million                 80486 non-null  float64
#  15  new_deaths_smoothed_per_million        89262 non-null  float64
#  16  reproduction_rate                      75391 non-null  float64
#  17  icu_patients                           9496 non-null   float64
#  18  icu_patients_per_million               9496 non-null   float64
#  19  hosp_patients                          11792 non-null  float64
#  20  hosp_patients_per_million              11792 non-null  float64
#  21  weekly_icu_admissions                  860 non-null    float64
#  22  weekly_icu_admissions_per_million      860 non-null    float64
#  23  weekly_hosp_admissions                 1496 non-null   float64
#  24  weekly_hosp_admissions_per_million     1496 non-null   float64
#  25  new_tests                              42244 non-null  float64
#  26  total_tests                            41934 non-null  float64
#  27  total_tests_per_thousand               41934 non-null  float64
#  28  new_tests_per_thousand                 42244 non-null  float64
#  29  new_tests_smoothed                     48953 non-null  float64
#  30  new_tests_smoothed_per_thousand        48953 non-null  float64
#  31  positive_rate                          46132 non-null  float64
#  32  tests_per_case                         45533 non-null  float64
#  33  tests_units                            50540 non-null  object
#  34  total_vaccinations                     13506 non-null  float64
#  35  people_vaccinated                      12727 non-null  float64
#  36  people_fully_vaccinated                9998 non-null   float64
#  37  new_vaccinations                       11328 non-null  float64
#  38  new_vaccinations_smoothed              22951 non-null  float64
#  39  total_vaccinations_per_hundred         13506 non-null  float64
#  40  people_vaccinated_per_hundred          12727 non-null  float64
#  41  people_fully_vaccinated_per_hundred    9998 non-null   float64
#  42  new_vaccinations_smoothed_per_million  22951 non-null  float64
#  43  stringency_index                       78978 non-null  float64
#  44  population                             93118 non-null  float64
#  45  population_density                     87164 non-null  float64
#  46  median_age                             84058 non-null  float64
#  47  aged_65_older                          83110 non-null  float64
#  48  aged_70_older                          83592 non-null  float64
#  49  gdp_per_capita                         84320 non-null  float64
#  50  extreme_poverty                        57024 non-null  float64
#  51  cardiovasc_death_rate                  84457 non-null  float64
#  52  diabetes_prevalence                    86458 non-null  float64
#  53  female_smokers                         66100 non-null  float64
#  54  male_smokers                           65131 non-null  float64
#  55  handwashing_facilities                 42428 non-null  float64
#  56  hospital_beds_per_thousand             76984 non-null  float64
#  57  life_expectancy                        89010 non-null  float64
#  58  human_development_index                84629 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 42.2+ MB

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'])

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93737 entries, 0 to 93736
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93737 non-null  object
#  1   continent                              89302 non-null  object
#  2   location                               93737 non-null  object
#  3   date                                   93737 non-null  datetime64[ns]
#  4   total_cases                            90755 non-null  float64
#  5   new_cases                              90754 non-null  float64
#  6   new_cases_smoothed                     89742 non-null  float64
#  7   total_deaths                           80800 non-null  float64
#  8   new_deaths                             80958 non-null  float64
#  9   new_deaths_smoothed                    89742 non-null  float64
#  10  total_cases_per_million                90270 non-null  float64
#  11  new_cases_per_million                  90269 non-null  float64
#  12  new_cases_smoothed_per_million         89262 non-null  float64
#  13  total_deaths_per_million               80328 non-null  float64
#  14  new_deaths_per_million                 80486 non-null  float64
#  15  new_deaths_smoothed_per_million        89262 non-null  float64
#  16  reproduction_rate                      75391 non-null  float64
#  17  icu_patients                           9496 non-null   float64
#  18  icu_patients_per_million               9496 non-null   float64
#  19  hosp_patients                          11792 non-null  float64
#  20  hosp_patients_per_million              11792 non-null  float64
#  21  weekly_icu_admissions                  860 non-null    float64
#  22  weekly_icu_admissions_per_million      860 non-null    float64
#  23  weekly_hosp_admissions                 1496 non-null   float64
#  24  weekly_hosp_admissions_per_million     1496 non-null   float64
#  25  new_tests                              42244 non-null  float64
#  26  total_tests                            41934 non-null  float64
#  27  total_tests_per_thousand               41934 non-null  float64
#  28  new_tests_per_thousand                 42244 non-null  float64
#  29  new_tests_smoothed                     48953 non-null  float64
#  30  new_tests_smoothed_per_thousand        48953 non-null  float64
#  31  positive_rate                          46132 non-null  float64
#  32  tests_per_case                         45533 non-null  float64
#  33  tests_units                            50540 non-null  object
#  34  total_vaccinations                     13506 non-null  float64
#  35  people_vaccinated                      12727 non-null  float64
#  36  people_fully_vaccinated                9998 non-null   float64
#  37  new_vaccinations                       11328 non-null  float64
#  38  new_vaccinations_smoothed              22951 non-null  float64
#  39  total_vaccinations_per_hundred         13506 non-null  float64
#  40  people_vaccinated_per_hundred          12727 non-null  float64
#  41  people_fully_vaccinated_per_hundred    9998 non-null   float64
#  42  new_vaccinations_smoothed_per_million  22951 non-null  float64
#  43  stringency_index                       78978 non-null  float64
#  44  population                             93118 non-null  float64
#  45  population_density                     87164 non-null  float64
#  46  median_age                             84058 non-null  float64
#  47  aged_65_older                          83110 non-null  float64
#  48  aged_70_older                          83592 non-null  float64
#  49  gdp_per_capita                         84320 non-null  float64
#  50  extreme_poverty                        57024 non-null  float64
#  51  cardiovasc_death_rate                  84457 non-null  float64
#  52  diabetes_prevalence                    86458 non-null  float64
#  53  female_smokers                         66100 non-null  float64
#  54  male_smokers                           65131 non-null  float64
#  55  handwashing_facilities                 42428 non-null  float64
#  56  hospital_beds_per_thousand             76984 non-null  float64
#  57  life_expectancy                        89010 non-null  float64
#  58  human_development_index                84629 non-null  float64
# dtypes: datetime64[ns](1), float64(54), object(4)
# memory usage: 42.2+ MB

# %%
df_copy.sort_values('date',inplace=True)
df_copy.head()
# Out:
#       iso_code      continent   location       date  total_cases  new_cases  \
# 3349       ARG  South America  Argentina 2020-01-01          NaN        NaN
# 54531      MEX  North America     Mexico 2020-01-01          NaN        NaN
# 3350       ARG  South America  Argentina 2020-01-02          NaN        NaN
# 54532      MEX  North America     Mexico 2020-01-02          NaN        NaN
# 3351       ARG  South America  Argentina 2020-01-03          NaN        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 3349                  NaN           NaN         NaN                  NaN  ...
# 54531                 NaN           NaN         NaN                  NaN  ...
# 3350                  NaN           NaN         NaN                  NaN  ...
# 54532                 NaN           NaN         NaN                  NaN  ...
# 3351                  NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 3349        18933.907              0.6                191.032
# 54531       17336.469              2.5                152.783
# 3350        18933.907              0.6                191.032
# 54532       17336.469              2.5                152.783
# 3351        18933.907              0.6                191.032
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 3349                  5.50            16.2          27.7
# 54531                13.06             6.9          21.4
# 3350                  5.50            16.2          27.7
# 54532                13.06             6.9          21.4
# 3351                  5.50            16.2          27.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 3349                      NaN                        5.00            76.67
# 54531                  87.847                        1.38            75.05
# 3350                      NaN                        5.00            76.67
# 54532                  87.847                        1.38            75.05
# 3351                      NaN                        5.00            76.67
#
#        human_development_index
# 3349                     0.845
# 54531                    0.779
# 3350                     0.845
# 54532                    0.779
# 3351                     0.845
#
# [5 rows x 59 columns]

# %%
file_name = 'world_sorted.xlsx'
df_copy.to_excel(file_name)

# %% [markdown]
# # Questions to be answered

# %% [markdown]
# Q. Which country is having highest number of cases?
#
# Ans: The country having highest number of cases is United States(6,147,547,405).
#
# Q. Which country is having lowest number of cases?
#
# Ans: Kiribati is having the lowest cases till now(27).
#
# Q. Which country is having highest number of deaths?
#
# Ans: The country having highest number of deaths is United States(125,406,660).
#
# Q. Which country is having lowest number of deaths?
#
# Ans: Vanautu is having the lowest deaths till now(42).
#
# Q. Which country is most vaccinated?
#
# Ans: China is the country with highest number of vaccination(20,866,595,700).

# %% [markdown]
# https://public.tableau.com/app/profile/t.lalitha/viz/majorproject-questionsandanswers/Questionsandanswers
